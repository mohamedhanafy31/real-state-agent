# %% [markdown]
# # RAG System Exploration Notebook
#
# Use this notebook to test and explore the RAG system components.

# %%
# Example usage
import sys
sys.path.append('..')

from src import RAGPipeline
from src.utils import setup_logging

setup_logging(level="INFO")

# Initialize pipeline
pipeline = RAGPipeline(config_path="../config/settings.yaml")

# Build or load index
# pipeline.build_index(...)
# pipeline.load_index(...)

# Query
# response = pipeline.query("سؤال")
# print(response['answer'])
